# %%
import pandas as pd
df = pd.read_csv(r"G:\Udemy\DATA SCIENCE ineuron\VS Code\Internship_project_Bike_Share_Prediction\Data\Bike_Share_Day 2.csv")
df.shape
# Out:
# (731, 16)

# %%
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    object
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    object
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    object
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(8), object(4)
# memory usage: 91.5+ KB

# %%
for col in df.columns:
    print(f"Unique records of {col} are {len(df[col].unique())}")
    print("="*50)
# Out:
# Unique records of instant are 731
# ==================================================
# Unique records of dteday are 731
# ==================================================
# Unique records of season are 4
# ==================================================
# Unique records of yr are 2
# ==================================================
# Unique records of mnth are 12
# ==================================================
# Unique records of holiday are 2
# ==================================================
# Unique records of weekday are 7
# ==================================================
# Unique records of workingday are 2
# ==================================================
# Unique records of weathersit are 3
# ==================================================
# Unique records of temp are 499
# ==================================================
# Unique records of atemp are 690
# ==================================================
# Unique records of hum are 595
# ==================================================
# Unique records of windspeed are 650
# ==================================================
# Unique records of casual are 606
# ==================================================
# Unique records of registered are 679
# ==================================================
# Unique records of cnt are 696
# ==================================================

# %%
df.weathersit.unique()
# Out:
# array([2, 1, 3], dtype=int64)

# %%
df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df1 = df.drop(['dteday','cnt'],axis=1)

# %%
df1
# Out:
#      instant  season    yr mnth  holiday    weekday  workingday  weathersit  \
# 0          1  spring  2011  Jan        0   saturday           0           2
# 1          2  spring  2011  Jan        0     sunday           0           2
# 2          3  spring  2011  Jan        0     monday           1           1
# 3          4  spring  2011  Jan        0    tuesday           1           1
# 4          5  spring  2011  Jan        0  wednesday           1           1
# ..       ...     ...   ...  ...      ...        ...         ...         ...
# 726      727  spring  2012  dec        0   thursday           1           2
# 727      728  spring  2012  dec        0     friday           1           2
# 728      729  spring  2012  dec        0   saturday           0           2
# 729      730  spring  2012  dec        0     sunday           0           1
# 730      731  spring  2012  dec        0     monday           1           2
#
#          temp     atemp       hum  windspeed  casual  registered
# 0    0.344167  0.363625  0.805833   0.160446     331         654
# 1    0.363478  0.353739  0.696087   0.248539     131         670
# 2    0.196364  0.189405  0.437273   0.248309     120        1229
# 3    0.200000  0.212122  0.590435   0.160296     108        1454
# 4    0.226957  0.229270  0.436957   0.186900      82        1518
# ..        ...       ...       ...        ...     ...         ...
# 726  0.254167  0.226642  0.652917   0.350133     247        1867
# 727  0.253333  0.255046  0.590000   0.155471     644        2451
# 728  0.253333  0.242400  0.752917   0.124383     159        1182
# 729  0.255833  0.231700  0.483333   0.350754     364        1432
# 730  0.215833  0.223487  0.577500   0.154846     439        2290
#
# [731 rows x 14 columns]

# %%
[fea for fea in df.columns if df[fea].dtypes == 'O']
# Out:
# ['dteday', 'season', 'mnth', 'weekday']

# %%
import pickle
import pandas as pd

# %%
df = pd.read_pickle(r"G:\Udemy\DATA SCIENCE ineuron\VS Code\Internship_project_Bike_Share_Prediction\saved_models\0\model\model.pkl")

# %%
df.corr()
# Out:
#              instant        yr   holiday  workingday  weathersit      temp  \
# instant     1.000000  0.866025  0.016145   -0.004337   -0.021477  0.150580
# yr          0.866025  1.000000  0.007954   -0.002013   -0.048727  0.047604
# holiday     0.016145  0.007954  1.000000   -0.253023   -0.034627 -0.028556
# workingday -0.004337 -0.002013 -0.253023    1.000000    0.061200  0.052660
# weathersit -0.021477 -0.048727 -0.034627    0.061200    1.000000 -0.120602
# temp        0.150580  0.047604 -0.028556    0.052660   -0.120602  1.000000
# atemp       0.152638  0.046106 -0.032507    0.052182   -0.121583  0.991702
# hum         0.016375 -0.110651 -0.015937    0.024327    0.591045  0.126963
# windspeed  -0.112620 -0.011817  0.006292   -0.018796    0.039511 -0.157944
# casual      0.275255  0.248546  0.054274   -0.518044   -0.247353  0.543285
# registered  0.659623  0.594248 -0.108745    0.303907   -0.260388  0.540012
# cnt         0.628830  0.566710 -0.068348    0.061156   -0.297391  0.627494
#
#                atemp       hum  windspeed    casual  registered       cnt
# instant     0.152638  0.016375  -0.112620  0.275255    0.659623  0.628830
# yr          0.046106 -0.110651  -0.011817  0.248546    0.594248  0.566710
# holiday    -0.032507 -0.015937   0.006292  0.054274   -0.108745 -0.068348
# workingday  0.052182  0.024327  -0.018796 -0.518044    0.303907  0.061156
# weathersit -0.121583  0.591045   0.039511 -0.247353   -0.260388 -0.297391
# temp        0.991702  0.126963  -0.157944  0.543285    0.540012  0.627494
# atemp       1.000000  0.139988  -0.183643  0.543864    0.544192  0.631066
# hum         0.139988  1.000000  -0.248489 -0.077008   -0.091089 -0.100659
# windspeed  -0.183643 -0.248489   1.000000 -0.167613   -0.217449 -0.234545
# casual      0.543864 -0.077008  -0.167613  1.000000    0.395282  0.672804
# registered  0.544192 -0.091089  -0.217449  0.395282    1.000000  0.945517
# cnt         0.631066 -0.100659  -0.234545  0.672804    0.945517  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize= (10,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>
